# %%
import os,sys
import pandas as pd

import glob
# root='D:\\NTU\\110MIS\\webcrawler\\crawl\\'
root = 'D:\\NTU\\110MIS\\gitdata\\IM_final_project\\data'

dirlist = [ item for item in os.listdir(root) if os.path.isdir(os.path.join(root, item)) ]
dirlist
# Out:
# [' 許伯&簡芝—倉鼠人',
#  '.ipynb_checkpoints',
#  'AC草影水族',
#  'Astor',
#  'Brian Cuisine Inc',
#  'BugCat Capoo',
#  'Celeste Wu 大沛',
#  'CFABC 鵝肉麵',
#  'Cheap',
#  'DeluCat迪鹿',
#  'Dinter',
#  'Dr. Ivan 6',
#  'Dream Chef Home 夢幻廚房在我家',
#  'GARY G腿講NBA故事',
#  'Gary蓋瑞',
#  'Hello Catie',
#  'heyitsmindy',
#  'HowFun',
#  "I'm Charlie",
#  'It‘s Jcnana 蒨蒨',
#  'Jessica Lin',
#  'Jinnytty 企鵝妹 윰찌',
#  'Joeman',
#  'J爸',
#  'Kimi紀卜心',
#  'MASAの料理ABC',
#  'Meg Lu',
#  'NanaQ',
#  'NyoNyoTV妞妞TV',
#  'Onion Man',
#  'RICO',
#  'Sandy&Mandy',
#  'SelinaCheng Life',
#  'SKIMMY 你的網路閨蜜',
#  'Stand up',
#  'Stand up, Brian! 博恩站起來！',
#  'Taiwan Bar',
#  'Tang_ful',
#  'Toyz',
#  'VITO維特',
#  'WACKYBOYS 反骨男孩',
#  '一隻阿圓 I am CIRCLE',
#  '丁特dinter',
#  '三個字SunGuts',
#  '上班不要看 NSFW',
#  '丹妮婊姐星球',
#  '亮生活  Bright Side',
#  '克里斯餐桌',
#  '六指淵 Huber',
#  '冏冏電台',
#  '劉芒',
#  '千千進食中',
#  '南瓜 Pumpkin',
#  '反正我很閒',
#  '古娃娃WawaKu',
#  '台灣大胃王丁丁 Ding-Ding',
#  '吃貨豪豪 HowHowEat',
#  '呱吉',
#  '啟點文 化',
#  '啾啾妹',
# ...

# %%
dirlists = []
for i in dirlist:
    if(i != '.ipynb_checkpoints'):
        dirlists.append(i)
dirlists
# Out:
# [' 許伯&簡芝—倉鼠人',
#  'AC草影水族',
#  'Astor',
#  'Brian Cuisine Inc',
#  'BugCat Capoo',
#  'Celeste Wu 大沛',
#  'CFABC 鵝肉麵',
#  'Cheap',
#  'DeluCat迪鹿',
#  'Dinter',
#  'Dr. Ivan 6',
#  'Dream Chef Home 夢幻廚房在我家',
#  'GARY G腿講NBA故事',
#  'Gary蓋瑞',
#  'Hello Catie',
#  'heyitsmindy',
#  'HowFun',
#  "I'm Charlie",
#  'It‘s Jcnana 蒨蒨',
#  'Jessica Lin',
#  'Jinnytty 企鵝妹 윰찌',
#  'Joeman',
#  'J爸',
#  'Kimi紀卜心',
#  'MASAの料理ABC',
#  'Meg Lu',
#  'NanaQ',
#  'NyoNyoTV妞妞TV',
#  'Onion Man',
#  'RICO',
#  'Sandy&Mandy',
#  'SelinaCheng Life',
#  'SKIMMY 你的網路閨蜜',
#  'Stand up',
#  'Stand up, Brian! 博恩站起來！',
#  'Taiwan Bar',
#  'Tang_ful',
#  'Toyz',
#  'VITO維特',
#  'WACKYBOYS 反骨男孩',
#  '一隻阿圓 I am CIRCLE',
#  '丁特dinter',
#  '三個字SunGuts',
#  '上班不要看 NSFW',
#  '丹妮婊姐星球',
#  '亮生活  Bright Side',
#  '克里斯餐桌',
#  '六指淵 Huber',
#  '冏冏電台',
#  '劉芒',
#  '千千進食中',
#  '南瓜 Pumpkin',
#  '反正我很閒',
#  '古娃娃WawaKu',
#  '台灣大胃王丁丁 Ding-Ding',
#  '吃貨豪豪 HowHowEat',
#  '呱吉',
#  '啟點文 化',
#  '啾啾妹',
#  '啾啾鞋',
#  '囂搞',
#  '大蛇丸',
# ...

# %%
import os,sys
import pandas as pd

import glob
root='D:\\NTU\\110MIS\\webcrawler\\crawl\\'
# root = 'D:\\NTU\\110MIS\\gitdata\\IM_final_project\\data'

mylist = [ item for item in os.listdir(root) if os.path.isdir(os.path.join(root, item)) ]
mylist
# Out:
# ['.ipynb_checkpoints',
#  'AC草影水族',
#  'Astor',
#  'Brian Cuisine Inc',
#  'BugCat Capoo',
#  'Celeste Wu 大沛',
#  'CFABC 鵝肉麵',
#  'Cheap',
#  'DeluCat迪鹿',
#  'Dinter',
#  'Dr. Ivan 6',
#  'Dream Chef Home 夢幻廚房在我家',
#  'GARY G腿講NBA故事',
#  'Gary蓋瑞',
#  'Hello Catie',
#  'heyitsmindy',
#  'HowFun',
#  "I'm Charlie",
#  'It‘s Jcnana 蒨蒨',
#  'Jessica Lin',
#  'Jinnytty 企鵝妹 윰찌',
#  'Joeman',
#  'J爸',
#  'Kimi紀卜心',
#  'MASAの料理ABC',
#  'Meg Lu',
#  'NanaQ',
#  'NyoNyoTV妞妞TV',
#  'Onion Man',
#  'RICO',
#  'Sandy&Mandy',
#  'SelinaCheng Life',
#  'SKIMMY 你的網路閨蜜',
#  'Stand up',
#  'Taiwan Bar',
#  'Tang_ful',
#  'Toyz',
#  'VITO維特',
#  'WACKYBOYS 反骨男孩',
#  '一隻阿圓 I am CIRCLE',
#  '丁特dinter',
#  '三個字SunGuts',
#  '上班不要看 NSFW',
#  '丹妮婊姐星球',
#  '亮生活 Bright Side',
#  '克里斯餐桌',
#  '六指淵 Huber',
#  '冏冏電台',
#  '劉芒',
#  '千千進食中',
#  '南瓜 Pumpkin',
#  '厭世甜點店',
#  '反正我很閒',
#  '古娃娃WawaKu',
#  '台灣大胃王丁丁 Ding-Ding',
#  '吃貨豪豪 HowHowEat',
#  '呱吉',
#  '啟點文化',
#  '啾啾妹',
#  '啾啾鞋',
#  '囂搞',
#  '大蛇丸',
#  '大麻煩',
# ...

# %%
path = 'D:\\NTU\\110MIS\\webcrawler\\crawl\\'
newpath = 'D:\\NTU\\110MIS\\gitdata\\IM_final_project\\data\\'
for i in dirlists:
    if(i in mylist):
        fpath = path + i
        extension = 'csv'
        os.chdir(fpath)
        result = glob.glob('*.{}'.format(extension))
        for files in result:
            current = fpath  +'\\' + files
            newpaths = newpath + i +'\\' + files
            print(newpaths)
            os.replace(current, newpaths)
    else:
        print(i)
# Out:
#  許伯&簡芝—倉鼠人
# Stand up, Brian! 博恩站起來！
# 亮生活  Bright Side
# 啟點文 化
# 導演 好了沒
# 眼球中央電視台
# 黃氏 兄弟

# %%
for i in dirlists:
    fpath = newpath + i
    extension = 'csv'
    os.chdir(fpath)
    result = glob.glob('*.{}'.format(extension))
#     print(result)
    for file in result:
        try:
            oldfile =  fpath + '\\' + file 
            newfile =  fpath + '\\mobile01.csv'
            if(file.split('_')[1] == 'mobile01.csv'):
                os.rename(oldfile, newfile)
        except:
            continue

# %%
for i in mylist:
    if(i in dirlists):
        continue
    else:
        print(i)
# Out:
# .ipynb_checkpoints
# 亮生活 Bright Side
# 克里斯餐桌
# 南瓜 Pumpkin
# 厭世甜點店
# 台灣大胃王丁丁 Ding-Ding
# 吃貨豪豪 HowHowEat
# 啟點文化
# 好味小姐 Lady Flavor
# 導演好了沒
# 小田太太の玩樂廚房
# 巧兒灶咖 Ciao! Kitchen
# 希露弟弟啃雞腿
# 找蔬食Traveggo
# 拉姆有幾噗
# 明聰
# 柴犬Nana和阿楞的一天
# 特盛吃貨艾嘉Abby Big Eater
# 簡單哥
# 糖餃子Sweet Dumpling
# 索艾克
# 臺灣蟻窟AntsFormosa
# 菜單研究所
# 許伯&簡芝—倉鼠人
# 詹姆士姆士流官方專屬頻道
# 豆漿- SoybeanMilk
# 貓咪&狗狗搞笑 Cat&dog Funny videos
# 路路 LULU
# 連環泡有芒果影片專區
# 阿坤的水族遊樂園
# 黃小米 Mii
# 黃聖凱
# 黃阿瑪的後宮生活
